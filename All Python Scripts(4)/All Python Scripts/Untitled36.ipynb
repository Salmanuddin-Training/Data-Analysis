# %%
print("============== Alpha Inventory System ==============\n\n")
product = 0
def switch():
    print("1. Product Master\n2. Customer Master\n3. Bill Master\n")
    option = int(input("Select Option : ")) 
    product = 0
    num = 0
    pro_list = []
    def pro_master():
        while(num != 4):
            print("\n1. Add Product\n2. View Inventory\n3. Search Product\n4. Delete Product\n")
            option1=int(input("Select option: "))
            if(option1 == 1):
                product = int(input("\nEnter number of product to add:"))
                for i in range(0,product):
                    name=input("\nEnter product name:")
                    price=float(input("Enter price of the product:"))
                    quantity=int(input("Enter quantity of the product:"))
                    pro_list.append([name,price,quantity])
                    
  
            if(option1 == 2):  
                print("Product\tPrice\tQuantity\n")
                try:              
                    for i in range(0,product): 
                        print(pro_list[i][0],"\t",pro_list[i][1],"\t",pro_list[i][2],"\n")
                except:
                    print("No Products found")     
            
            
            if(option1 == 3 ):
                item = input("Enter Product name : ")
                try:
                    for i in range(len(pro_list)):
                        if item == pro_list[i] in pro_list:
                            print(pro_list)
                        else:
                            print("item doesnt exist")
                except:
                    print("no such item found")
                           
                    

    def customer_master():
        pass
    
    
    def bill_master():
        pass
        
        
    def exit():
        print("==========Thanks=========")
        
    dict_var = {
        1 : pro_master,
        2 : customer_master,
        3 : bill_master,
        4 : exit
    }
            
    dict_var.get(option)()
    
for i in range(0,4):
    switch()
# Out:
# ============== Alpha Inventory System ==============
#
#
# 1. Product Master
# 2. Customer Master
# 3. Bill Master
#
# Select Option : 1
#
# 1. Add Product
# 2. View Inventory
# 3. Search Product
# 4. Delete Product
#
# Select option: 1
#
# Enter number of product to add:1
#
# Enter product name:Laptop
# Enter price of the product:45000
# Enter quantity of the product:5
#
# 1. Add Product
# 2. View Inventory
# 3. Search Product
# 4. Delete Product
#
# Select option: 2
# Product	Price	Quantity
#
# Laptop 	 45000.0 	 5
#
#
# 1. Add Product
# 2. View Inventory
# 3. Search Product
# 4. Delete Product

# %%
# Out:
# 1. Open Account
# 2. Display Account
# 3. Deposit
# 4. Withdraw
# 5. Close Account
# 0. Exit
# Enter Choice : 2
# Enter Account Number : 1002
# Account Number :  1002
# Name :  Akarshit
# Branch :  AXIS
# Balance :  500000
# 1. Open Account
# 2. Display Account
# 3. Deposit
# 4. Withdraw
# 5. Close Account
# 0. Exit
# Enter Choice : 1
# Last acc. number  1003
