# %%
students_attempts = int(input("How many times you attempts this exam?"))
AptiFlag= True
EnglishFlag = True
MathFlag = True
GkFlag = True
ans = ''
score=0
bonus = 0
if (students_attempts ==1):
    
        
    for i in range(1,6):
        print("Subjects are : \n1.Aptitude \n2.English \n3.Math \n4.GK \n5.Exit")
        choose = int(input("\nChoose one subject = "))
                
        if choose == 1:
            if AptiFlag:
                AptiFlag = False
                ans= input("\nWhat is the average of first five multiples of 12:")
                if (ans =='36'):
                      score = score+10
            else:
                print("You have already attempt this subject choose another....")
        elif choose == 2:
            if EnglishFlag:
                EnglishFlag = False

                ans = input("\nAntonym of Throwback:")
                if (ans == 'Gift'):
                    score = score+10
            else:
                print("You have already attempt this subject choose another....")
        elif choose == 3:
            if MathFlag:
                Mathflag = False
                ans = input("\nIf 1=3 \n2=3\n3=5 \n4=4 \n5=4 \nThen, 6=?")
                if (ans=='3'):
                    score=score+10
            else:
                print("You have already attempt this subject choose another....")
        elif choose == 4:
            if GkFlag:
                GkFlag = False
                ans = input("\nWhich Country is called the land of rising sun?")
                if (ans == 'Japan'):
                      score = score+10
            else:
                print("You have already attempt this subject choose another....")
        else:
            print("You exit from test......")
            break
    if score == 10:
        total_score = score+bonus
        if total_score >= 10:
            print("Your Total Score is : ",total_score,"\n Your IQ level is below")
    elif score == 20:
        bonus = 2
        total_score = score+bonus
        if total_score >=20:
            print("Your Total Score is : ",total_score,"\n Your IQ level is average")
    elif score == 30:
        bonus = 5
        total_score = score+bonus
        if total_score >=30:
            print("Your Total Score is : ",total_score,"\n Your are Intelligent")
    elif score == 40:
        bonus = 10
        total_score = score+bonus
        if total_score >=50:
            print("Your Total score is : ",total_score,"\n You are Genious")
    else:
        print("You need to do hard work")
else:
    print("You can not attempt the quiz")
# Out:
# How many times you attempts this exam?1
# Subjects are :
# 1.Aptitude
# 2.English
# 3.Math
# 4.GK
# 5.Exit
#
# Choose one subject = 1
#
# What is the average of first five multiples of 12:36
# Subjects are :
# 1.Aptitude
# 2.English
# 3.Math
# 4.GK
# 5.Exit
#
# Choose one subject = 2
#
# Antonym of Throwback:Gift
# Subjects are :
# 1.Aptitude
# 2.English
# 3.Math
# 4.GK
# 5.Exit
#
# Choose one subject = 3
#
# If 1=3
# 2=3
# 3=5
# 4=4
# 5=4
# Then, 6=?3
# Subjects are :
# 1.Aptitude
# 2.English
# 3.Math
# 4.GK
# 5.Exit
#
# Choose one subject = 4
#
# Which Country is called the land of rising sun?Japan
# Subjects are :
# 1.Aptitude
# 2.English
# 3.Math
# 4.GK
# 5.Exit
#
# Choose one subject = 5
# You exit from test......
# Your Total score is :  50
#  You are Genious

# %%
class Employee:
    '''This class deals with an employee details'''
    """def __init__(self):
        self.empid=101
        self.name='John'
        self.salary=45000"""
    def acceptDetails(self):
        self.empid=int(input('Enter empid :'))
        self.name =input('Enter name:')
        self.salary=input('Enter salary :')
    
    def displayDetails(self):
        print('==== Displaying employee details ====')
        print('Employee ID     : ',self.empid)
        print("Emloyee Name    : ",self.name)
        print("Employee Salary : ",self.salary)

emp1 = Employee() #object/instance creation
emp1.acceptDetails()
emp1.displayDetails() #callinf /calling displaydeta....

emp2 = Employee() #object/instance creation
emp2.acceptDetails()
emp2.displayDetails()
# Out:
# Enter empid :1
# Enter name:Kirti
# Enter salary :60000
# ==== Displaying employee details ====
# Employee ID     :  1
# Emloyee Name    :  Kirti
# Employee Salary :  60000
# Enter empid :2
# Enter name:Monika
# Enter salary :70000
# ==== Displaying employee details ====
# Employee ID     :  2
# Emloyee Name    :  Monika
# Employee Salary :  70000
